# %%
# %matplotlib inline

# %%
# Import dependencies

import matplotlib.pyplot as plt
import random

# %%
savings=[]
for i in range (0,12):
    i = random.randrange(1,1000,50)
    savings.append(i)
    
months = ["jan", "feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# %%
savings
# Out:
# [451, 551, 601, 951, 251, 251, 101, 551, 901, 701, 151, 951]

# %%
plt.plot(months, savings)
plt.xlabel("Month")
plt.ylabel("Savings($)")
plt.title("Saving Account Results")
plt.show()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis);

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot()
ax.plot(x_axis, y_axis, marker = "o", markersize = 20, color = "green", label="months")
ax.set_title('Fares',fontsize = 30, color="purple")
ax.legend("City of Boston")
ax.grid()

fig.savefig("plot1.png")

# %%
# Create the plot with ax.plt()
ax = plt.axes()

# %%
# Create the plot
plt.plot(x_axis, y_axis, linewidth = 2, marker ="*", color= "blue",label= "Boston")
plt.xlabel("Date")
plt.ylabel("Fare($)")

#set the y limit
plt.ylim(0, 45)

plt.title("PyBer Fare by Moth")
plt.grid()
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis, color="green", label='Boston')
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title
plt.title("Pyber Fare by Month")
# Add a legend
plt.legend()

# %%
plt.barh(x_axis, y_axis, color="green", label='Boston')
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title
plt.title("Pyber Fare by Month")
# Add a legend
plt.legend()

# %%
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(x_axis, y_axis, color ="magenta", label="Boston")
plt.gca().invert_yaxis()
plt.xlabel("Fare($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
plt.legend()

# %%
# Create a chart using the object method ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color='k', label="New York")
ax.legend()

# %%
# ax.plt horizontal bar chart
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color ="cyan", label ="Chicago")
ax.set_xlabel("Fare($)")
ax.set_ylabel("Date")
ax.set_title("Chicago")
ax.invert_yaxis()
ax.legend()

# %%
# Scatter Plot
plt.plot(x_axis, y_axis, 'o')

# %%
# Scatter Plot 2
plt.scatter(y_axis, x_axis, c='r', label= "Chigago")
plt.gca().invert_yaxis()
plt.xlabel("Fare($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
plt.legend()

# %%
y_axis_larger=[]
for data in y_axis:
    y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, c='r',s= y_axis_larger, label= "Chigago")
#plt.gca().invert_yaxis()
plt.xlabel("Fare($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
plt.legend()

# %%
new_list = [expression for item in list if conditional]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-8e1ea8ba77dc> in <module>
# ----> 1 new_list = [expression for item in list if conditional]
#
# TypeError: 'type' object is not iterable

# %%
plt.scatter(x_axis, y_axis, s= [i *3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, c= "skyblue", s=[i*5 for i in y_axis], alpha= 0.8,edgecolors="black", linewidth = 2, label = "Boston")
ax.invert_yaxis()
ax.set_xlim(0,50)
ax.set_xlabel('Date')
ax.set_ylabel("Fare($)")
ax.set_title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
colors = ["blue","yellow", "red", "gray", "skyblue", "orange", "purple", "black", "lavender", "lime", "pink", "gold"]
plt.subplots(figsize=(8, 8))
plt.pie(y_axis, labels=x_axis, colors= colors, autopct= '%1.1f%%', explode = explode_values)
plt.show()

# %%
fig, ax = plt.subplots(figsize =(8,8))
explode = max(y_axis)
ax.pie(y_axis, labels =x_axis, autopct='%1.1f%%', shadow=True, startangle=90, counterclock=False)
plt.show()

# %%
#plt.errirbar(x, y, yerr=<value>)

# %%
import statistics

# %%
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
import numpy as np
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.minorticks_on()
plt.gca().invert_yaxis()

# %%
np.arange(0, 51, step=5.0)
# Out:
# array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50.])
